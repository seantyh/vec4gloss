# %% [markdown]
# # Train Vec4Gloss

# %%
## reference: https://huggingface.co/course/chapter7/4

# %%
# %load_ext autoreload
# %autoreload 2
import sys
if "../src" not in sys.path:
    sys.path.append("../src")

# %%
from vec4gloss import check_hashes
from pathlib import Path
import numpy as np
from tqdm.auto import tqdm

# %% [markdown]
# ## Data dependencies

# %% [markdown]
# ```
# ../data/denoising_dataset_cwn/train/dataset.arrow a7ef3e
# ../data/defgen_dataset_cwn/train/dataset.arrow ea55fd
# ```

# %%
_ = check_hashes([
    "../data/denoising_dataset_cwn/train/dataset.arrow",
    "../data/defgen_dataset_cwn/train/dataset.arrow",
])
# Out:
# ../data/denoising_dataset_cwn/train/dataset.arrow a7ef3e
# ../data/defgen_dataset_cwn/train/dataset.arrow ea55fd

# %% [markdown]
# ## Prepare dataset

# %%
import numpy as np
from transformers import MT5ForConditionalGeneration, MT5TokenizerFast
from transformers import DataCollatorForSeq2Seq
import datasets
from datasets import load_metric

# %%
ds_denoise = datasets.load_from_disk("../data/denoising_dataset_cwn/")
ds_defgen = datasets.load_from_disk("../data/defgen_dataset_cwn")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_16837/484432448.py in <module>
#       1 ds_denoise = datasets.load_from_disk("../data/denoising_dataset_cwn/")
# ----> 2 ds_defgen = datasets.load_from_disk("../data/defgen_dataset_cwn")
#
# ~/miniconda3/lib/python3.9/site-packages/datasets/load.py in load_from_disk(dataset_path, fs, keep_in_memory)
#    1737         raise FileNotFoundError(f"Directory {dataset_path} not found")
#    1738     if fs.isfile(Path(dest_dataset_path, config.DATASET_INFO_FILENAME).as_posix()):
# -> 1739         return Dataset.load_from_disk(dataset_path, fs, keep_in_memory=keep_in_memory)
#    1740     elif fs.isfile(Path(dest_dataset_path, config.DATASETDICT_JSON_FILENAME).as_posix()):
#    1741         return DatasetDict.load_from_disk(dataset_path, fs, keep_in_memory=keep_in_memory)
#
# ~/miniconda3/lib/python3.9/site-packages/datasets/arrow_dataset.py in load_from_disk(dataset_path, fs, keep_in_memory)
#    1197             fs.download(src_dataset_path, dataset_path.as_posix(), recursive=True)
#    1198
# -> 1199         with open(Path(dataset_path, config.DATASET_STATE_JSON_FILENAME).as_posix(), encoding="utf-8") as state_file:
#    1200             state = json.load(state_file)
#    1201         with open(Path(dataset_path, config.DATASET_INFO_FILENAME).as_posix(), encoding="utf-8") as dataset_info_file:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/defgen_dataset_cwn/state.json'

# %%
tokenizer = MT5TokenizerFast.from_pretrained("google/mt5-base")
ds = datasets.load_from_disk("cwn_seq2seq_charlie_ds")
# Out:
# Downloading:   0%|          | 0.00/376 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.11M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/702 [00:00<?, ?B/s]

# %%
max_length = 256
def preprocess_fn(batch):    
    src_batch = tokenizer(batch["src"], 
                          max_length=max_length, truncation=True)
    with tokenizer.as_target_tokenizer():
      tgt_batch = tokenizer(batch["tgt"],
                            max_length=max_length, truncation=True)    
    return {
        **src_batch, "labels": tgt_batch["input_ids"]
    }

# %%
tokenized_ds = ds.map(preprocess_fn, batched=True, remove_columns=ds["train"].column_names)
# Out:
#   0%|          | 0/95 [00:00<?, ?ba/s]
#   0%|          | 0/28 [00:00<?, ?ba/s]

# %%
model = MT5ForConditionalGeneration.from_pretrained("google/mt5-base").to("cuda")
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, padding="longest")
# Out:
# Downloading:   0%|          | 0.00/2.17G [00:00<?, ?B/s]

# %% [markdown]
# ## Define BLEU metrics

# %%
metric = load_metric("sacrebleu")
# Out:
# Downloading builder script:   0%|          | 0.00/2.36k [00:00<?, ?B/s]

# %%
metric.compute(predictions=["中文數字"], references=[["中文數學"]], tokenize="char")
# Out:
# {'bp': 1.0,
#  'counts': [3, 2, 1, 0],
#  'precisions': [75.0, 66.66666666666667, 50.0, 50.0],
#  'ref_len': 4,
#  'score': 59.460355750136046,
#  'sys_len': 4,
#  'totals': [4, 3, 2, 1]}

# %%
def compute_metrics(eval_preds):
  preds, labels = eval_preds
  if isinstance(preds, tuple):
    preds = preds[0]
  
  decoded_preds = tokenizer.batch_decode(preds, skip_special_tokens=True)
  # Replace -100s in the labels as we can't decode them
  labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
  decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

  # Some simple post-processing
  decoded_preds = [pred.strip() for pred in decoded_preds]
  decoded_labels = [[label.strip()] for label in decoded_labels]

  result = metric.compute(predictions=decoded_preds, references=decoded_labels, 
                          tokenize="char")
  return {"bleu": result["score"]}

# %% [markdown]
# ## Trainer

# %%
import wandb
wandb.login()

# %%
from transformers import Seq2SeqTrainingArguments

args = Seq2SeqTrainingArguments(
    f"cwn_seq2seq_cherry",
    evaluation_strategy="steps",
    save_strategy="no",    
    learning_rate=1e-4,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    weight_decay=0.01,
    logging_steps=500,
    save_total_limit=3,
    num_train_epochs=3,
    report_to="wandb",
    run_name="cwn-seq2seq-cherry",
    predict_with_generate=True,    
)

# %%
train_ds = tokenized_ds["train"]
# test_ds = tokenized_ds["test"]
# train_ds = tokenized_ds["train"].select(range(100))
tokenized_ds["test"].shuffle(seed=6532)
test_ds = tokenized_ds["test"].select(range(200))

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 94727
#   Num Epochs = 3
#   Instantaneous batch size per device = 2
#   Total train batch size (w. parallel, distributed & accumulation) = 2
#   Gradient Accumulation steps = 1
#   Total optimization steps = 142092
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: seantyh (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220324_013557-36ryco66</code>
# Syncing run <strong><a href="https://wandb.ai/seantyh/huggingface/runs/36ryco66" target="_blank">cwn-seq2seq-cherry</a></strong> to <a href="https://wandb.ai/seantyh/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#     <div>
#
#       <progress value='129001' max='142092' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [129001/142092 8:54:26 < 54:14, 4.02 it/s, Epoch 2.72/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Bleu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>5.008700</td>
#       <td>3.651752</td>
#       <td>2.780459</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>3.020200</td>
#       <td>3.388342</td>
#       <td>4.237818</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>2.692900</td>
#       <td>3.200469</td>
#       <td>4.463003</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>2.639500</td>
#       <td>3.120623</td>
#       <td>5.144895</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>2.549900</td>
#       <td>3.051400</td>
#       <td>8.777265</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>2.494100</td>
#       <td>2.923128</td>
#       <td>8.310880</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>2.322700</td>
#       <td>2.885219</td>
#       <td>9.023786</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>2.471300</td>
#       <td>2.839002</td>
#       <td>9.927610</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>2.355000</td>
#       <td>2.782748</td>
#       <td>9.815332</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>2.210900</td>
#       <td>2.796220</td>
#       <td>10.963444</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>2.221200</td>
#       <td>2.727756</td>
#       <td>11.166487</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>2.256200</td>
#       <td>2.702136</td>
#       <td>12.652480</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>2.149900</td>
#       <td>2.680439</td>
#       <td>11.752311</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>2.099700</td>
#       <td>2.676708</td>
#       <td>11.661086</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td
td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>1.806200</td>
#       <td>2.192168</td>
#       <td>16.153322</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>1.790100</td>
#       <td>2.225450</td>
#       <td>16.846665</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>1.740700</td>
#       <td>2.173468</td>
#       <td>18.433454</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>1.767300</td>
#       <td>2.172713</td>
#       <td>17.981791</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>1.777500</td>
#       <td>2.154640</td>
#       <td>18.281895</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>1.694600</td>
#       <td>2.366032</td>
#       <td>13.662777</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>1.777000</td>
#       <td>2.144636</td>
#       <td>18.463293</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>1.722000</td>
#       <td>2.120471</td>
#       <td>17.406948</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>1.738600</td>
#       <td>2.122627</td>
#       <td>17.458828</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>1.742300</td>
#       <td>2.114788</td>
#       <td>16.778041</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>1.733100</td>
#       <td>2.108208</td>
#       <td>16.146372</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>1.621700</td>
#       <td>2.123829</td>
#       <td>17.248429</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>1.659700</td>
#       <td>2.093725</td>
#       <td>17.630794</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>1.660300</td>
#       <td>2.086378</td>
#       <td>18.616027</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>1.701400</td>
#       <td>2.056500</td>
#       <td>18.743737</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>1.624900</td>
#       <td>2.063148</td>
#       <td>17.876779</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>1.677300</td>
#       <td>2.048158</td>
#       <td>18.737189</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>1.638500</td>
#       <td>2.036412</td>
#       <td>17.400210</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>1.646200</td>
#       <td>2.033584</td>
#       <td>19.515303</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>1.638200</td>
#       <td>2.014538</td>
#       <td>18.351084</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>1.688800</td>
#       <td>1.978010</td>
#       <td>17.349000</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>1.695000</td>
#       <td>1.957834</td>
#       <td>20.827485</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>1.617100</td>
#       <td>1.955835</td>
#       <td>18.958006</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>1.599500</td>
#       <td>1.971767</td>
#       <td>19.753264</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>1.605900</td>
#       <td>1.951559</td>
#       <td>17.939006</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>1.630400</td>
#       <td>1.929178</td>
#       <td>17.909045</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>1.626500</td>
#       <td>1.934781</td>
#       <td>17.885560</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>1.532200</td>
#       <td>1.938505</td>
#       <td>19.429096</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>1.702100</td>
#       <td>1.898807</td>
#       <td>21.106221</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>1.533100</td>
#       <td>1.898601</td>
#       <td>21.043958</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>1.567900</td>
#       <td>1.904918</td>
#       <td>20.832599</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>1.593900</td>
#       <td>1.893549</td>
#       <td>20.779699</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>1.612600</td>
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
# ***** Running Evaluation *****
#   Num examples = 200
#   Batch size = 2
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=142092, training_loss=1.2878654471282147, metrics={'train_runtime': 35330.408, 'train_samples_per_second': 8.044, 'train_steps_per_second': 4.022, 'total_flos': 2.558515034110464e+16, 'train_loss': 1.2878654471282147, 'epoch': 3.0})

# %%
# !rm -rf cwn-seq2seq-cherry

# %%
trainer.save_model("cwn-seq2seq-cherry")
# Out:
# Saving model checkpoint to cwn-seq2seq-cherry
# Configuration saved in cwn-seq2seq-cherry/config.json
# Model weights saved in cwn-seq2seq-cherry/pytorch_model.bin
# tokenizer config file saved in cwn-seq2seq-cherry/tokenizer_config.json
# Special tokens file saved in cwn-seq2seq-cherry/special_tokens_map.json
# Copy vocab file to cwn-seq2seq-cherry/spiece.model

# %%
# !gsutil cp -r ./cwn-seq2seq-cherry gs://langon-us

# %% [markdown]
# ## Text generation

# %%
wandb.finish()

# %%
from transformers import pipeline
text2text_gen = pipeline("text2text-generation", model=model, tokenizer=tokenizer, device=0)
text2text_gen("唉唷。<唉唷>，好啦！你不要老是學那個電視上啦！")
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7fdb3eca8810>> (for pre_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _resume_backend(self)
#     326         if self.backend is not None:
#     327             logger.info("resuming backend")
# --> 328             self.backend.interface.publish_resume()
#     329
#     330     def _jupyter_teardown(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     579     def publish_resume(self) -> None:
#     580         resume = pb.ResumeRequest()
# --> 581         self._publish_resume(resume)
#     582
#     583     @abstractmethod
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_resume(self, resume)
#     277     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     278         rec = self._make_request(resume=resume)
# --> 279         self._publish(rec)
#     280
#     281     def _publish_run(self, run: pb.RunRecord) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_queue.py in _publish(self, record, local)
#      47     def _publish(self, record: "pb.Record", local: bool = None) -> None:
#      48         if self._process_check and self._process and not self._process.is_alive():
# ---> 49             raise Exception("The wandb backend process has shutdown")
#      50         if local:
#      51             record.control.local = local
#
# Exception: The wandb backend process has shutdown
# [{'generated_text': 'I。表不耐煩的語氣。'}]
# Error in callback <bound method _WandbInit._pause_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7fdb3eca8810>> (for post_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _pause_backend(self)
#     321                 res = self.run.log_code(root=None)
#     322                 logger.info("saved code: %s", res)
# --> 323             self.backend.interface.publish_pause()
#     324
#     325     def _resume_backend(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_pause(self)
#     571     def publish_pause(self) -> None:
#     572         pause = pb.PauseRequest()
# --> 573         self._publish_pause(pause)
#     574
#     575     @abstractmethod
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_shared.py in _publish_pause(self, pause)
#     273     def _publish_pause(self, pause: pb.PauseRequest) -> None:
#     274         rec = self._make_request(pause=pause)
# --> 275         self._publish(rec)
#     276
#     277     def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface_queue.py in _publish(self, record, local)
#      47     def _publish(self, record: "pb.Record", local: bool = None) -> None:
#      48         if self._process_check and self._process and not self._process.is_alive():
# ---> 49             raise Exception("The wandb backend process has shutdown")
#      50         if local:
#      51             record.control.local = local
#
# Exception: The wandb backend process has shutdown

# %%
text2text_gen("輪。雙方展開第4<輪>談判。")

# %%
text2text_gen("氣候暖化。會議中對<氣候暖化>議題交換意見。")

# %%
text2text_gen("終於。他們<終於>玩起來了。")
# Out:
# [{'generated_text': 'D。表從時間參考點起,直到最後的時間。'}]

# %%
text2text_gen("氣候暖化。會議中對<氣候暖化>議題交換意見。")
