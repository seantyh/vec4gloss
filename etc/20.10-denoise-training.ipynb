# %% [markdown]
# # Train Vec4Gloss - Denoise

# %%
## reference: https://huggingface.co/course/chapter7/4

# %%
# %env WANDB_PROJECT=vec4gloss
# Out:
# env: WANDB_PROJECT=vec4gloss

# %%
# %load_ext autoreload
# %autoreload 2
import sys
if "../src" not in sys.path:
    sys.path.append("../src")

# %%
from datetime import datetime
from pathlib import Path
from datasets import Dataset
import numpy as np
from tqdm.auto import tqdm
from vec4gloss import check_hashes

# %% [markdown]
# ## Data dependencies

# %% [markdown]
# ```
# ../data/denoising_dataset_cwn/train/dataset.arrow ad87fa
# ```

# %%
_ = check_hashes([
    "../data/denoising_dataset_cwn/train/dataset.arrow",    
])
# Out:
# ../data/denoising_dataset_cwn/train/dataset.arrow ad87fa

# %% [markdown]
# ## Prepare dataset

# %%
import numpy as np
from transformers import MT5ForConditionalGeneration, MT5TokenizerFast
from transformers import DataCollatorForSeq2Seq
import datasets
from datasets import load_metric

# %%
ds_denoise = datasets.load_from_disk("../data/denoising_dataset_cwn/")

# %%
print({k: len(v) for k, v in ds_denoise.items()})
# Out:
# {'train': 26118, 'test': 2903}

# %%
tokenizer = MT5TokenizerFast.from_pretrained("google/mt5-base")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_25285/2056947990.py in <module>
# ----> 1 tokenizer = MT5TokenizerFast.from_pretrained("google/mt5-base")
#
# ~/miniconda3/lib/python3.9/site-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1781                 logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
#    1782
# -> 1783         return cls._from_pretrained(
#    1784             resolved_vocab_files,
#    1785             pretrained_model_name_or_path,
#
# ~/miniconda3/lib/python3.9/site-packages/transformers/tokenization_utils_base.py in _from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, use_auth_token, cache_dir, *init_inputs, **kwargs)
#    1926         # Instantiate tokenizer.
#    1927         try:
# -> 1928             tokenizer = cls(*init_inputs, **init_kwargs)
#    1929         except OSError:
#    1930             raise OSError(
#
# ~/miniconda3/lib/python3.9/site-packages/transformers/models/t5/tokenization_t5_fast.py in __init__(self, vocab_file, tokenizer_file, eos_token, unk_token, pad_token, extra_ids, additional_special_tokens, **kwargs)
#     132                 )
#     133
# --> 134         super().__init__(
#     135             vocab_file,
#     136             tokenizer_file=tokenizer_file,
#
# ~/miniconda3/lib/python3.9/site-packages/transformers/tokenization_utils_fast.py in __init__(self, *args, **kwargs)
#     111         elif slow_tokenizer is not None:
#     112             # We need to convert a slow tokenizer to build the backend
# --> 113             fast_tokenizer = convert_slow_tokenizer(slow_tokenizer)
#     114         elif self.slow_tokenizer_class is not None:
#     115             # We need to create and convert a slow tokenizer to build the backend
#
# ~/miniconda3/lib/python3.9/site-packages/transformers/convert_slow_tokenizer.py in convert_slow_tokenizer(transformer_tokenizer)
#    1075     converter_class = SLOW_TO_FAST_CONVERTERS[tokenizer_class_name]
#    1076
# -> 1077     return converter_class(transformer_tokenizer).converted()
#
# ~/miniconda3/lib/python3.9/site-packages/transformers/convert_slow_tokenizer.py in __init__(self, *args)
#     428         m = model_pb2.ModelProto()
#     429         with open(self.original_tokenizer.vocab_file, "rb") as f:
# --> 430             m.ParseFromString(f.read())
#     431         self.proto = m
#     432
#
# KeyboardInterrupt:

# %% [markdown]
# ### Eye-balling

# %%
ds_denoise["train"][10:12]

# %%
tokenizer.convert_ids_to_tokens(tokenizer(ds_denoise["train"][10]["tgt"])["input_ids"])

# %% [markdown]
# ## Preprocess

# %%
max_length = 256

def preprocess_fn(batch):    
    src_batch = tokenizer(batch["src"], 
                          max_length=max_length, truncation=True)
    with tokenizer.as_target_tokenizer():
        tgt_batch = tokenizer(batch["tgt"],
                              max_length=max_length, truncation=True)    
    return {
        **src_batch, "labels": tgt_batch["input_ids"]
    }

# %%
drop_columns = ["cwnid", "src", "tgt"]
ds_denoise = ds_denoise.map(preprocess_fn, batched=True, remove_columns=drop_columns)

# %% [markdown]
# ### Eye-balling

# %%
print(" ".join(tokenizer.convert_ids_to_tokens(ds_denoise["train"][10]["input_ids"])))
print(" ".join(tokenizer.convert_ids_to_tokens(ds_denoise["train"][10]["labels"])))

# %% [markdown]
# ## Model definition

# %%
model = MT5ForConditionalGeneration.from_pretrained("google/mt5-base").to("cuda")
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, padding="longest")

# %% [markdown]
# ## Trainer

# %%
# import wandb
# wandb.login()

# %%
out_dir = Path("/mnt/md0/seantyh/vec4gloss")
if not out_dir.exists():
    out_dir = "vec4gloss"
print(out_dir)

# %%
from transformers import Seq2SeqTrainingArguments
timestamp = datetime.now().strftime("%y%m%d-%H%M")

args = Seq2SeqTrainingArguments(
    out_dir,
    evaluation_strategy="steps",
    save_strategy="epoch",    
    learning_rate=1e-4,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    logging_steps=100, # 10 for debug, else 500
    eval_steps=3000,
    save_total_limit=3,
    num_train_epochs=3,
    # report_to="wandb",
    run_name=f"denoising-{timestamp}",
    predict_with_generate=False,    
)

# %%
train_ds = ds_denoise["train"]
test_ds = ds_denoise["test"]
# train_ds = train_ds.select(range(100))
# test_ds = test_ds.select(range(200))

# %%
from transformers import Seq2SeqTrainer

trainer = Seq2SeqTrainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    data_collator=data_collator,
    tokenizer=tokenizer
)

# %%
trainer.train()

# %%
trainer.save_model(f"../data/models/vec4gloss-denoise-{timestamp}")
