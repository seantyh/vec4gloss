# %%
# %load_ext autoreload
# %autoreload 2
import sys
if "../src" not in sys.path:
    sys.path.append("../src")

# %%
from vec4gloss import check_hashes

# %% [markdown]
# ## Data dependencies

# %% [markdown]
# ```
#     (data) => ..\data\rating_raw_data_220707.csv 7dde1c
#     30.02 => ..\data\rating_materials.n10.csv bfe418
# ```

# %%
_ = check_hashes([
    "../data/rating_raw_data_220707.csv",
    "../data/rating_materials.n10.csv"
])
# Out:
# ..\data\rating_raw_data_220707.csv 7dde1c
# ..\data\rating_materials.n10.csv bfe418

# %% [markdown]
# ## Loading resources

# %%
import pandas as pd
data = pd.read_csv("../data/rating_raw_data_220707.csv")
item_data = pd.read_csv("../data/rating_materials.n10.csv", index_col=0)

# %%
data.shape, item_data.shape
# Out:
# ((5, 423), (140, 7))

# %%
items = item_data.to_dict(orient='records')

# %%
respmat = data.iloc[:, 3:].values

# %%
data.iloc[:,3:7]
# Out:
#   為下列何者的釋義   釋義詮釋度 Semantic explainability  釋義語法自然度 Syntactic naturality  \
# 0      D.以                               3                             5
# 1     C.及時                               1                             4
# 2     C.及時                               1                             5
# 3      D.以                               1                             5
# 4     C.及時                               2                             5
#
#   為下列何者的釋義.1
# 0      D.異質性
# 1      D.異質性
# 2      D.異質性
# 3      D.異質性
# 4      D.異質性

# %%
resp_data = []
import numpy as np
for item_i, item_x in enumerate(items):
    resp = {**item_x}
    choices = [x.split(".")[1]
                       for x in respmat[:, item_i*3+0].tolist()]
    resp["correct"] = np.mean([x==item_x["target"] for x in choices])
    resp["sem_mean"] = np.mean(respmat[:, item_i*3+1].tolist())    
    resp["syn_mean"] = np.mean(respmat[:, item_i*3+2].tolist()) 
    resp["sem_sd"] = np.std(respmat[:, item_i*3+1].tolist(), ddof=1)
    resp["syn_sd"] = np.std(respmat[:, item_i*3+2].tolist(), ddof=1)
    resp_data.append(resp)

# %%
resp_df = pd.DataFrame.from_records(resp_data)

# %%
def se(x):
    return np.std(x, ddof=1)/np.sqrt(len(x))
resp_df.pivot_table(index=["from"], 
                    values=["correct", "sem_mean", "syn_mean"], 
                    aggfunc=["mean", se])
# Out:
#              mean                          se
#           correct sem_mean syn_mean   correct  sem_mean  syn_mean
# from
# ASBC        0.855   2.5300     4.51  0.041130  0.215377  0.124849
# CWN         0.950   4.4700     4.82  0.024602  0.148873  0.095035
# vec4gloss   0.880   3.5075     4.58  0.027467  0.164045  0.092886

# %%
resp_df.loc[resp_df.loc[:,"from"]=="ASBC"]\
       .pivot_table(index=["pos"], 
                    values=["correct", "sem_mean", "syn_mean"], 
                    aggfunc=["mean", se])
# Out:
#        mean                          se
#     correct sem_mean syn_mean   correct  sem_mean  syn_mean
# pos
# D      0.84     2.76     4.74  0.071802  0.430813  0.160693
# N      0.86     1.92     4.32  0.079162  0.396877  0.342799
# O      0.86     2.70     4.50  0.103494  0.445471  0.204939
# V      0.86     2.74     4.48  0.084591  0.455143  0.273577

# %%
resp_df.loc[resp_df.loc[:,"from"]=="vec4gloss"]\
       .pivot_table(index=["pos"], 
                    values=["correct", "sem_mean", "syn_mean"], 
                    aggfunc=["mean", se])
# Out:
#        mean                          se
#     correct sem_mean syn_mean   correct  sem_mean  syn_mean
# pos
# D      0.84     3.75     4.69  0.064236  0.305347  0.179751
# N      0.94     3.18     4.14  0.035836  0.351208  0.249252
# O      0.85     3.47     4.70  0.059604  0.323558  0.161245
# V      0.89     3.63     4.79  0.057078  0.341598  0.095669

# %% [markdown]
# ## Output Hashes

# %% [markdown]
# ```
# ..\data\rating_response_stat.csv a04c24
# ```

# %%
data_path = "../data/rating_response_stat.csv"
resp_df.to_csv(data_path, index=False)
_ = check_hashes([data_path])
# Out:
# ..\data\rating_response_stat.csv a04c24

# %% [markdown]
# ## Eye-balling

# %%
resp_df.query("syn_mean<4")
# Out:
#     target ans pos       from item_id                      definition  \
# 1      異質性   D   N  vec4gloss    N-15                   形容具有多個性質或性質的。
# 6        紙   D   N  vec4gloss    N-11                  以紙張為主要材質製成的紙張。
# 25       愛   D   O  vec4gloss    O-16                   形容愛惜並愛惜特定對象的。
# 47     開發中   B   O       ASBC    O-59            特定事件在一段時間內發生不久的特定階段。
# 52     合併症   B   N       ASBC    N-58             疾病症狀由一個醫療體內產生病症的疾病。
# 64      需要   B   N  vec4gloss    N-07                    特定對象所需要的所有權。
# 70    水到渠成   C   V       ASBC    V-55              比喻前述事件發展到成熟的情況或發展。
# 71     一窩蜂   D   D       ASBC    D-50                    比喻嗜好特定對象的怪獸。
# 79     封閉性   B   N       ASBC    N-53            形容比喻不侷限於狹小範圍，不與外界溝通。
# 87       弦   C   N  vec4gloss    N-23                       繫在兩條線上的線。
# 90      中上   A   O       ASBC    O-54                      等級不在兩端的部份。
# 96       昆   B   N  vec4gloss    N-05                          昆蟲的文化。
# 100     問題   D   O        CWN    O-04       形容特定對象有需要被解決的困難，通常會製造麻煩的。
# 110   比比皆是   A   V       ASBC    V-51               形容兩個以上程度漸進且超過預期的。
# 124     無名   A   O       ASBC    O-58                 形容沒有人認同或沒有交情的人。
# 128      層   A   N  vec4gloss    N-22                        描述程度的程度。
# 135     下來   C   D  vec4gloss    D-20  表狀態從過去持續到參考時點，強調其狀態從過去持續到參考時點。
# 138      騷   C   V  vec4gloss    V-05               形容味道像羊或狐的，基本味覺之一。
#
#                      options  correct  sem_mean  syn_mean    sem_sd    syn_sd
# 1        A.之內 B.素 C.反應 D.異質性      1.0       3.8       1.8  0.447214  0.447214
# 6            A.干 B.洲 C.對 D.紙      1.0       3.4       2.0  1.516575  0.707107
# 25           A.喲 B.而 C.據 D.愛      1.0       3.2       1.8  1.095445  0.836660
# 47      A.深層 B.開發中 C.亞太 D.於焉      0.6       2.8       3.6  0.836660  1.140175
# 52      A.樂府 B.合併症 C.套餐 D.情意      1.0       3.2       1.8  0.836660  1.303840
# 64          A.料 B.需要 C.撢 D.卡      1.0       1.4       3.8  0.894427  1.303840
# 70     A.劃定 B.承繼 C.水到渠成 D.良善      1.0       4.8       3.6  0.447214  1.140175
# 71      A.同聲 B.何妨 C.方才 D.一窩蜂      1.0       1.0       3.4  0.000000  1.816590
# 79      A.演進 B.封閉性 C.大一 D.牌樓      1.0       2.4       3.0  0.547723  1.581139
# 87         A.語言 B.廣場 C.弦 D.流      1.0       2.4       3.6  0.894427  1.341641
# 90       A.中上 B.沿著 C.寬頻 D.像是      1.0       2.4       3.6  0.547723  1.341641
# 96          A.文 B.昆 C.水 D.文字      1.0       1.2       2.4  0.447214  1.673320
# 100        A.淨 B.唉唷 C.從 D.問題      1.0       4.6       3.4  0.547723  1.140175
# 110  A.比比皆是 B.等閒視之 C.印有 D.駕馭      0.8       1.8       2.4  1.095445  1.341641
# 124      A.無名 B.木造 C.而論 D.國定      1.0       2.2       3.6  1.643168  1.673320
# 128        A.層 B.趣 C.番茄 D.祖父      1.0       1.2       2.4  0.447214  1.140175
# 135    A.一樣 B.著實 C.下來 D.曾幾何時      0.2       2.8       1.4  1.483240  0.547723
# 138       A.睡覺 B.寫信 C.騷 D.改為      1.0       2.8       3.2  1.483240  1.788854

# %%
resp_df.query("sem_mean<3").sort_values("correct", ascending=False)
# Out:
#     target ans pos       from item_id                      definition  \
# 87       弦   C   N  vec4gloss    N-23                       繫在兩條線上的線。
# 96       昆   B   N  vec4gloss    N-05                          昆蟲的文化。
# 68      小鬼   A   N       ASBC    N-57                         指人能力不足。
# 71     一窩蜂   D   D       ASBC    D-50                    比喻嗜好特定對象的怪獸。
# 79     封閉性   B   N       ASBC    N-53            形容比喻不侷限於狹小範圍，不與外界溝通。
# 80      應否   C   D       ASBC    D-56                   表對事件的疑問，詢問原因。
# 4       比較   D   D  vec4gloss    D-21                          表程度加深。
# 88       嬌   C   V  vec4gloss    V-13                 形容有花植物的花朵長出並舒展。
# 90      中上   A   O       ASBC    O-54                      等級不在兩端的部份。
# 98      旅店   B   N       ASBC    N-52                     住家房屋內用餐的場所。
# 64      需要   B   N  vec4gloss    N-07                    特定對象所需要的所有權。
# 117     中小   D   O  vec4gloss    O-23                     形容程度較低或範圍小。
# 121     環球   B   O       ASBC    O-53                    環繞太陽一周所需的時間。
# 124     無名   A   O       ASBC    O-58                 形容沒有人認同或沒有交情的人。
# 128      層   A   N  vec4gloss    N-22                        描述程度的程度。
# 134     感應   C   V       ASBC    V-53                    受到刺激而產生情緒反應。
# 137     中西   A   O       ASBC    O-57                     歐洲與美洲國家的通稱。
# 138      騷   C   V  vec4gloss    V-05               形容味道像羊或狐的，基本味覺之一。
# 65      知性   D   N       ASBC    N-51                   能夠瞭解外界的事物的特性。
# 139     看法   C   N  vec4gloss    N-09                     對特定對象持有的看法。
# 54     活生生   C   O  vec4gloss    O-24                  形容自然生長而非人工飼養的。
# 8       主控   A   V       ASBC    V-57    對特定事件做出如何進行的決定，並暗示與說話者的認知不同。
# 53      長足   C   O       ASBC    O-50                      比喻事件發展的基礎。
# 51      害死   A   V       ASBC    V-58                         生物失去生命。
# 22      急遽   A   D       ASBC    D-59                        形容事件急迫的。
# 29       月   D   O  vec4gloss    O-07                  地球環繞太陽一周所需的時間。
# 110   比比皆是   A   V       ASBC    V-51               形容兩個以上程度漸進且超過預期的。
# 31    好不容易   A   D  vec4gloss    D-10          表說話者主觀評價程度高，帶有誇張語氣或情感。
# 76      山羌   A   N       ASBC    N-56              中國古代地名，在今山東省泗水縣東方。
# 99       壓   A   V  vec4gloss    V-24                     比喻將金額依等份計算。
# 133     一定   C   O        CWN    O-02                        形容特別指出的。
# 106     藥廠   C   N       ASBC    N-54                    專門從事前述行業的商店。
# 125     產學   B   N       ASBC    N-55          研究以發展體力、增強體質為主的科學研究單位。
# 122     可要   C   D       ASBC    D-53               表說話者主觀認為後述事件可能發生。
# 30      年頭   C   N  vec4gloss    N-24                             過去。
# 63       蒙   D   V  vec4gloss    V-06                   因他人勝過自己而得到好處。
# 11      可就   D   D       ASBC    D-55          表說話者主觀評價程度高，帶有誇張語氣或情感。
# 132     加以   C   D  vec4gloss    D-19                 表加強說話者對陳述內容的肯定。
# 103      正   B   D  vec4gloss    D-06                  表順著特定對象進行後述事件。
# 34       燈   C   N  vec4gloss    N-13                    比喻具有特定功能的器具。
# 97      刺進   A   V       ASBC    V-50                  物體表面或特定部位向外凸出。
# 91       呼   D   O  vec4gloss    O-10                   以口語媒介引述或陳述訊息。
# 47     開發中   B   O       ASBC    O-59            特定事件在一段時間內發生不久的特定階段。
# 0       及時   C   O  vec4gloss    O-18                  形容在事件發生的時間點之後。
# 92       后   A   N  vec4gloss    N-12                    比喻在特定對象在的場合。
# 136     一字   D   D       ASBC    D-58                        表一個人單獨地。
# 38      放榜   B   V       ASBC    V-59                      比喻在競爭中被淘汰。
# 94      明牌   C   N       ASBC    N-50                   比喻在競爭中被淘汰的對象。
# 44       拋   D   V  vec4gloss    V-22                 比喻臉部顯示出特定表情或情緒。
# 45       崇   B   O  vec4gloss    O-11                       位置處於後述地點。
# 12      中介   B   O  vec4gloss    O-22                  與特定對象相關的責任或事件。
# 135     下來   C   D  vec4gloss    D-20  表狀態從過去持續到參考時點，強調其狀態從過去持續到參考時點。
# 74       晉   D   V  vec4gloss    V-12                      比喻在競爭中被淘汰。
# 107     漸染   C   D  vec4gloss    D-23           比喻受到特定對象的影響而逐漸產生類似變化。
# 55      靠著   A   O       ASBC    O-51                        引介動作的方向。
#
#                      options  correct  sem_mean  syn_mean    sem_sd    syn_sd
# 87         A.語言 B.廣場 C.弦 D.流      1.0       2.4       3.6  0.894427  1.341641
# 96          A.文 B.昆 C.水 D.文字      1.0       1.2       2.4  0.447214  1.673320
# 68      A.小鬼 B.基隆市 C.絕症 D.肚皮      1.0       1.2       5.0  0.447214  0.000000
# 71      A.同聲 B.何妨 C.方才 D.一窩蜂      1.0       1.0       3.4  0.000000  1.816590
# 79      A.演進 B.封閉性 C.大一 D.牌樓      1.0       2.4       3.0  0.547723  1.581139
# 80      A.咯咯咯 B.活活 C.應否 D.不配      1.0       2.8       4.8  1.788854  0.447214
# 4      A.到時候 B.反過來 C.剛好 D.比較      1.0       1.8       5.0  1.303840  0.000000
# 88        A.沉痛 B.佈局 C.嬌 D.比照      1.0       1.4       4.6  0.894427  0.894427
# 90       A.中上 B.沿著 C.寬頻 D.像是      1.0       2.4       3.6  0.547723  1.341641
# 98      A.買盤 B.旅店 C.經常性 D.老天      1.0       1.0       5.0  0.000000  0.000000
# 64          A.料 B.需要 C.撢 D.卡      1.0       1.4       3.8  0.894427  1.303840
# 117        A.有機 B.準 C.喔 D.中小      1.0       2.6       4.8  1.341641  0.447214
# 121      A.公教 B.環球 C.聯外 D.軍用      1.0       1.0       4.8  0.000000  0.447214
# 124      A.無名 B.木造 C.而論 D.國定      1.0       2.2       3.6  1.643168  1.673320
# 128        A.層 B.趣 C.番茄 D.祖父      1.0       1.2       2.4  0.447214  1.140175
# 134     A.直航 B.歇業 C.感應 D.站出來      1.0       1.8       5.0  0.836660  0.000000
# 137      A.中西 B.頂級 C.加護 D.明式      1.0       1.0       5.0  0.000000  0.000000
# 138       A.睡覺 B.寫信 C.騷 D.改為      1.0       2.8       3.2  1.483240  1.788854
# 65       A.聖神 B.浪花 C.品系 D.知性      1.0       2.0       4.2  1.000000  1.095445
# 139      A.份子 B.人才 C.看法 D.傷感      1.0       1.8       5.0  0.836660  0.000000
# 54         A.據 B.凡 C.活生生 D.趁      1.0       1.6       5.0  0.894427  0.000000
# 8        A.主控 B.下海 C.探頭 D.攀上      1.0       2.2       4.2  1.095445  1.095445
# 53       A.英屬 B.麻辣 C.長足 D.駐華      1.0       1.6       5.0  0.894427  0.000000
# 51       A.害死 B.具名 C.甚少 D.聽障      1.0       2.2       5.0  1.303840  0.000000
# 22      A.急遽 B.自應 C.轟隆 D.會不會      1.0       2.8       4.4  1.788854  0.894427
# 29           A.嗟 B.單 C.噯 D.月      1.0       1.8       5.0  1.788854  0.000000
# 110  A.比比皆是 B.等閒視之 C.印有 D.駕馭      0.8       1.8       2.4  1.095445  1.341641
# 31     A.好不容易 B.汲汲 C.悄悄 D.八成      0.8       2.2       5.0  0.836660  0.000000
# 76      A.山羌 B.舉世 C.國際賽 D.來看      0.8       1.0       5.0  0.000000  0.000000
# 99         A.壓 B.恢復 C.延長 D.住      0.8       1.0       4.4  0.000000  0.894427
# 133        A.總 B.老式 C.一定 D.等      0.8       2.8       4.0  2.049390  1.414214
# 106      A.強棒 B.福山 C.藥廠 D.週六      0.8       1.0       4.6  0.000000  0.894427
# 125    A.月眉 B.產學 C.通緝犯 D.文學界      0.8       1.6       4.6  1.341641  0.547723
# 122     A.忽地 B.終日 C.可要 D.忽然間      0.8       2.6       5.0  1.516575  0.000000
# 30         A.友 B.合約 C.年頭 D.圈      0.8       1.2       4.4  0.447214  0.894427
# 63          A.怔 B.依據 C.挑 D.蒙      0.6       1.8       4.4  0.836660  1.341641
# 11       A.難保 B.切勿 C.鼎力 D.可就      0.6       1.2       5.0  0.447214  0.000000
# 132       A.照舊 B.瞬 C.加以 D.總之      0.6       2.0       4.8  1.414214  0.447214
# 103        A.即將 B.正 C.恐 D.怎麼      0.6       1.6       4.4  0.894427  0.894427
# 34           A.甲 B.毛 C.燈 D.圍      0.6       1.2       4.8  0.447214  0.447214
# 97     A.刺進 B.與日俱增 C.放生 D.燃起      0.6       1.2       5.0  0.447214  0.000000
# 91         A.外交 B.坡 C.安啦 D.呼      0.6       1.6       5.0  1.341641  0.000000
# 47      A.深層 B.開發中 C.亞太 D.於焉      0.6       2.8       3.6  0.836660  1.140175
# 0         A.哦荷荷 B.呀 C.及時 D.以      0.6       1.6       4.8  0.894427  0.447214
# 92         A.后 B.蓋 C.南非 D.短線      0.4       1.0       4.0  0.000000  1.224745
# 136  A.柔聲 B.無時無刻 C.從早到晚 D.一字      0.4       1.0       4.8  0.000000  0.447214
# 38       A.解套 B.放榜 C.休養 D.咬牙      0.2       1.0       5.0  0.000000  0.000000
# 94       A.小生 B.西湖 C.明牌 D.磚牆      0.2       1.0       5.0  0.000000  0.000000
# 44         A.分化 B.知道 C.中 D.拋      0.2       1.0       5.0  0.000000  0.000000
# 45         A.數位 B.崇 C.亞 D.下屬      0.2       1.0       5.0  0.000000  0.000000
# 12        A.同時 B.中介 C.乃至 D.遍      0.2       1.8       4.8  1.303840  0.447214
# 135    A.一樣 B.著實 C.下來 D.曾幾何時      0.2       2.8       1.4  1.483240  0.547723
# 74          A.氣惱 B.平 C.咬 D.晉      0.2       1.4       5.0  0.547723  0.000000
# 107        A.縱 B.右 C.漸染 D.合計      0.0       1.4       5.0  0.894427  0.000000
# 55      A.靠著 B.有關於 C.跟著 D.開卷      0.0       2.4       5.0  1.341641  0.000000

# %%
resp_df.query("syn_mean<4 & sem_mean >3")
# Out:
#     target ans pos       from item_id                 definition  \
# 1      異質性   D   N  vec4gloss    N-15              形容具有多個性質或性質的。
# 6        紙   D   N  vec4gloss    N-11             以紙張為主要材質製成的紙張。
# 25       愛   D   O  vec4gloss    O-16              形容愛惜並愛惜特定對象的。
# 52     合併症   B   N       ASBC    N-58        疾病症狀由一個醫療體內產生病症的疾病。
# 70    水到渠成   C   V       ASBC    V-55         比喻前述事件發展到成熟的情況或發展。
# 100     問題   D   O        CWN    O-04  形容特定對象有需要被解決的困難，通常會製造麻煩的。
#
#                    options  correct  sem_mean  syn_mean    sem_sd    syn_sd
# 1      A.之內 B.素 C.反應 D.異質性      1.0       3.8       1.8  0.447214  0.447214
# 6          A.干 B.洲 C.對 D.紙      1.0       3.4       2.0  1.516575  0.707107
# 25         A.喲 B.而 C.據 D.愛      1.0       3.2       1.8  1.095445  0.836660
# 52    A.樂府 B.合併症 C.套餐 D.情意      1.0       3.2       1.8  0.836660  1.303840
# 70   A.劃定 B.承繼 C.水到渠成 D.良善      1.0       4.8       3.6  0.447214  1.140175
# 100      A.淨 B.唉唷 C.從 D.問題      1.0       4.6       3.4  0.547723  1.140175

# %%
resp_df.query("syn_mean>4 & sem_mean <3")
# Out:
#     target ans pos       from item_id                    definition  \
# 0       及時   C   O  vec4gloss    O-18                形容在事件發生的時間點之後。
# 4       比較   D   D  vec4gloss    D-21                        表程度加深。
# 8       主控   A   V       ASBC    V-57  對特定事件做出如何進行的決定，並暗示與說話者的認知不同。
# 11      可就   D   D       ASBC    D-55        表說話者主觀評價程度高，帶有誇張語氣或情感。
# 12      中介   B   O  vec4gloss    O-22                與特定對象相關的責任或事件。
# 22      急遽   A   D       ASBC    D-59                      形容事件急迫的。
# 29       月   D   O  vec4gloss    O-07                地球環繞太陽一周所需的時間。
# 30      年頭   C   N  vec4gloss    N-24                           過去。
# 31    好不容易   A   D  vec4gloss    D-10        表說話者主觀評價程度高，帶有誇張語氣或情感。
# 34       燈   C   N  vec4gloss    N-13                  比喻具有特定功能的器具。
# 38      放榜   B   V       ASBC    V-59                    比喻在競爭中被淘汰。
# 44       拋   D   V  vec4gloss    V-22               比喻臉部顯示出特定表情或情緒。
# 45       崇   B   O  vec4gloss    O-11                     位置處於後述地點。
# 51      害死   A   V       ASBC    V-58                       生物失去生命。
# 53      長足   C   O       ASBC    O-50                    比喻事件發展的基礎。
# 54     活生生   C   O  vec4gloss    O-24                形容自然生長而非人工飼養的。
# 55      靠著   A   O       ASBC    O-51                      引介動作的方向。
# 63       蒙   D   V  vec4gloss    V-06                 因他人勝過自己而得到好處。
# 65      知性   D   N       ASBC    N-51                 能夠瞭解外界的事物的特性。
# 68      小鬼   A   N       ASBC    N-57                       指人能力不足。
# 74       晉   D   V  vec4gloss    V-12                    比喻在競爭中被淘汰。
# 76      山羌   A   N       ASBC    N-56            中國古代地名，在今山東省泗水縣東方。
# 80      應否   C   D       ASBC    D-56                 表對事件的疑問，詢問原因。
# 88       嬌   C   V  vec4gloss    V-13               形容有花植物的花朵長出並舒展。
# 91       呼   D   O  vec4gloss    O-10                 以口語媒介引述或陳述訊息。
# 94      明牌   C   N       ASBC    N-50                 比喻在競爭中被淘汰的對象。
# 97      刺進   A   V       ASBC    V-50                物體表面或特定部位向外凸出。
# 98      旅店   B   N       ASBC    N-52                   住家房屋內用餐的場所。
# 99       壓   A   V  vec4gloss    V-24                   比喻將金額依等份計算。
# 103      正   B   D  vec4gloss    D-06                表順著特定對象進行後述事件。
# 106     藥廠   C   N       ASBC    N-54                  專門從事前述行業的商店。
# 107     漸染   C   D  vec4gloss    D-23         比喻受到特定對象的影響而逐漸產生類似變化。
# 117     中小   D   O  vec4gloss    O-23                   形容程度較低或範圍小。
# 121     環球   B   O       ASBC    O-53                  環繞太陽一周所需的時間。
# 122     可要   C   D       ASBC    D-53             表說話者主觀認為後述事件可能發生。
# 125     產學   B   N       ASBC    N-55        研究以發展體力、增強體質為主的科學研究單位。
# 132     加以   C   D  vec4gloss    D-19               表加強說話者對陳述內容的肯定。
# 134     感應   C   V       ASBC    V-53                  受到刺激而產生情緒反應。
# 136     一字   D   D       ASBC    D-58                      表一個人單獨地。
# 137     中西   A   O       ASBC    O-57                   歐洲與美洲國家的通稱。
# 139     看法   C   N  vec4gloss    N-09                   對特定對象持有的看法。
#
#                      options  correct  sem_mean  syn_mean    sem_sd    syn_sd
# 0         A.哦荷荷 B.呀 C.及時 D.以      0.6       1.6       4.8  0.894427  0.447214
# 4      A.到時候 B.反過來 C.剛好 D.比較      1.0       1.8       5.0  1.303840  0.000000
# 8        A.主控 B.下海 C.探頭 D.攀上      1.0       2.2       4.2  1.095445  1.095445
# 11       A.難保 B.切勿 C.鼎力 D.可就      0.6       1.2       5.0  0.447214  0.000000
# 12        A.同時 B.中介 C.乃至 D.遍      0.2       1.8       4.8  1.303840  0.447214
# 22      A.急遽 B.自應 C.轟隆 D.會不會      1.0       2.8       4.4  1.788854  0.894427
# 29           A.嗟 B.單 C.噯 D.月      1.0       1.8       5.0  1.788854  0.000000
# 30         A.友 B.合約 C.年頭 D.圈      0.8       1.2       4.4  0.447214  0.894427
# 31     A.好不容易 B.汲汲 C.悄悄 D.八成      0.8       2.2       5.0  0.836660  0.000000
# 34           A.甲 B.毛 C.燈 D.圍      0.6       1.2       4.8  0.447214  0.447214
# 38       A.解套 B.放榜 C.休養 D.咬牙      0.2       1.0       5.0  0.000000  0.000000
# 44         A.分化 B.知道 C.中 D.拋      0.2       1.0       5.0  0.000000  0.000000
# 45         A.數位 B.崇 C.亞 D.下屬      0.2       1.0       5.0  0.000000  0.000000
# 51       A.害死 B.具名 C.甚少 D.聽障      1.0       2.2       5.0  1.303840  0.000000
# 53       A.英屬 B.麻辣 C.長足 D.駐華      1.0       1.6       5.0  0.894427  0.000000
# 54         A.據 B.凡 C.活生生 D.趁      1.0       1.6       5.0  0.894427  0.000000
# 55      A.靠著 B.有關於 C.跟著 D.開卷      0.0       2.4       5.0  1.341641  0.000000
# 63          A.怔 B.依據 C.挑 D.蒙      0.6       1.8       4.4  0.836660  1.341641
# 65       A.聖神 B.浪花 C.品系 D.知性      1.0       2.0       4.2  1.000000  1.095445
# 68      A.小鬼 B.基隆市 C.絕症 D.肚皮      1.0       1.2       5.0  0.447214  0.000000
# 74          A.氣惱 B.平 C.咬 D.晉      0.2       1.4       5.0  0.547723  0.000000
# 76      A.山羌 B.舉世 C.國際賽 D.來看      0.8       1.0       5.0  0.000000  0.000000
# 80      A.咯咯咯 B.活活 C.應否 D.不配      1.0       2.8       4.8  1.788854  0.447214
# 88        A.沉痛 B.佈局 C.嬌 D.比照      1.0       1.4       4.6  0.894427  0.894427
# 91         A.外交 B.坡 C.安啦 D.呼      0.6       1.6       5.0  1.341641  0.000000
# 94       A.小生 B.西湖 C.明牌 D.磚牆      0.2       1.0       5.0  0.000000  0.000000
# 97     A.刺進 B.與日俱增 C.放生 D.燃起      0.6       1.2       5.0  0.447214  0.000000
# 98      A.買盤 B.旅店 C.經常性 D.老天      1.0       1.0       5.0  0.000000  0.000000
# 99         A.壓 B.恢復 C.延長 D.住      0.8       1.0       4.4  0.000000  0.894427
# 103        A.即將 B.正 C.恐 D.怎麼      0.6       1.6       4.4  0.894427  0.894427
# 106      A.強棒 B.福山 C.藥廠 D.週六      0.8       1.0       4.6  0.000000  0.894427
# 107        A.縱 B.右 C.漸染 D.合計      0.0       1.4       5.0  0.894427  0.000000
# 117        A.有機 B.準 C.喔 D.中小      1.0       2.6       4.8  1.341641  0.447214
# 121      A.公教 B.環球 C.聯外 D.軍用      1.0       1.0       4.8  0.000000  0.447214
# 122     A.忽地 B.終日 C.可要 D.忽然間      0.8       2.6       5.0  1.516575  0.000000
# 125    A.月眉 B.產學 C.通緝犯 D.文學界      0.8       1.6       4.6  1.341641  0.547723
# 132       A.照舊 B.瞬 C.加以 D.總之      0.6       2.0       4.8  1.414214  0.447214
# 134     A.直航 B.歇業 C.感應 D.站出來      1.0       1.8       5.0  0.836660  0.000000
# 136  A.柔聲 B.無時無刻 C.從早到晚 D.一字      0.4       1.0       4.8  0.000000  0.447214
# 137      A.中西 B.頂級 C.加護 D.明式      1.0       1.0       5.0  0.000000  0.000000
# 139      A.份子 B.人才 C.看法 D.傷感      1.0       1.8       5.0  0.836660  0.000000
